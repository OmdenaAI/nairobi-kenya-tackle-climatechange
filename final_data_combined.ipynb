# %% [markdown]
# # DATA PREPROCESSING

# %%
#TO PRE-PROCESS DATA\n",
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#TO READ CSV FILE
data = pd.read_csv("final_data_combined.csv")

# %%
data
# Out:
#       lat     lon  XCO2 (mol CO2/mol dry)  XCO2PREC (mol CO2/mol dry)  Month  \
# 0    -5.0  38.750                0.000414                5.420000e-08      2
# 1    -5.0  38.750                0.000414                3.570000e-08      3
# 2    -5.0  38.750                0.000404                5.430000e-08      3
# 3    -5.0  38.750                0.000398                2.360000e-08      1
# 4    -5.0  38.750                0.000399                1.800000e-08      3
# ...   ...     ...                     ...                         ...    ...
# 4226  4.5  35.000                0.000407                4.340000e-08     11
# 4227  4.5  35.625                0.000415                5.680000e-08      5
# 4228  4.5  35.625                0.000414                4.840000e-08      1
# 4229  4.5  35.625                0.000401                4.260000e-08     12
# 4230  4.5  35.625                0.000411                3.390000e-08      9
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4231 entries, 0 to 4230
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   lat                         4231 non-null   float64
#  1   lon                         4231 non-null   float64
#  2   XCO2 (mol CO2/mol dry)      4231 non-null   float64
#  3   XCO2PREC (mol CO2/mol dry)  4231 non-null   float64
#  4   Month                       4231 non-null   int64
#  5   Year                        4231 non-null   int64
#  6   DATE                        4231 non-null   object
#  7   population                  3563 non-null   float64
#  8   primary_fuel                818 non-null    object
#  9   commissioning_year          818 non-null    float64
#  10  capacity_mw                 818 non-null    float64
#  11  city_ascii                  2212 non-null   object
#  12  capital                     1509 non-null   object
# ...

# %%
data.isnull().sum()
# Out:
# lat                              0
# lon                              0
# XCO2 (mol CO2/mol dry)           0
# XCO2PREC (mol CO2/mol dry)       0
# Month                            0
# Year                             0
# DATE                             0
# population                     668
# primary_fuel                  3413
# commissioning_year            3413
# capacity_mw                   3413
# city_ascii                    2019
# capital                       2722
# city_pop_2022                 2605
# month                            0
# brightness                       0
# scan                             0
# track                            0
# bright_t31                       0
# frp                              0
# dtype: int64

# %%
data.shape
# Out:
# (4231, 20)

# %%
data['primary_fuel'].isnull().sum()
# Out:
# 3413

# %%
data['primary_fuel'].notnull().sum()
# Out:
# 818

# %%
data[data['primary_fuel'].notnull()]
# Out:
#       lat     lon  XCO2 (mol CO2/mol dry)  XCO2PREC (mol CO2/mol dry)  Month  \
# 67   -4.5  39.375                0.000415                2.940000e-08     11
# 68   -4.5  39.375                0.000415                2.940000e-08     11
# 69   -4.5  39.375                0.000415                2.940000e-08     11
# 70   -4.5  39.375                0.000415                2.940000e-08     11
# 71   -4.5  39.375                0.000415                2.940000e-08     11
# ...   ...     ...                     ...                         ...    ...
# 3870  2.5  36.250                0.000415                6.500000e-08      6
# 3871  2.5  36.250                0.000405                7.000000e-08      3
# 3874  2.5  36.250                0.000410                7.190000e-08      6
# 3875  2.5  36.250                0.000409                5.190000e-08     11
# 3876  2.5  36.250                0.000409                5.520000e-08      2
#
# ...

# %%
#Create Year-Month column
data['year_month'] = data['Year'].astype(str) + "-" + data['Month'].astype(str)

# %%
#data = data.drop(['year_month'], axis=1)

# %%
data
# Out:
#       lat     lon  XCO2 (mol CO2/mol dry)  XCO2PREC (mol CO2/mol dry)  Month  \
# 0    -5.0  38.750                0.000414                5.420000e-08      2
# 1    -5.0  38.750                0.000414                3.570000e-08      3
# 2    -5.0  38.750                0.000404                5.430000e-08      3
# 3    -5.0  38.750                0.000398                2.360000e-08      1
# 4    -5.0  38.750                0.000399                1.800000e-08      3
# ...   ...     ...                     ...                         ...    ...
# 4226  4.5  35.000                0.000407                4.340000e-08     11
# 4227  4.5  35.625                0.000415                5.680000e-08      5
# 4228  4.5  35.625                0.000414                4.840000e-08      1
# 4229  4.5  35.625                0.000401                4.260000e-08     12
# 4230  4.5  35.625                0.000411                3.390000e-08      9
#
# ...

# %%
data.dtypes
# Out:
# lat                           float64
# lon                           float64
# XCO2 (mol CO2/mol dry)        float64
# XCO2PREC (mol CO2/mol dry)    float64
# Month                           int64
# Year                            int64
# DATE                           object
# population                    float64
# primary_fuel                   object
# commissioning_year            float64
# capacity_mw                   float64
# city_ascii                     object
# capital                        object
# city_pop_2022                 float64
# month                           int64
# brightness                    float64
# scan                          float64
# track                         float64
# bright_t31                    float64
# frp                           float64
# year_month                     object
# dtype: object

# %%
data['primary_fuel'] = data['primary_fuel'].fillna("Unknown")

# %%
data[(data['primary_fuel'] == "Unknown") ]
# Out:
#       lat     lon  XCO2 (mol CO2/mol dry)  XCO2PREC (mol CO2/mol dry)  Month  \
# 0    -5.0  38.750                0.000414                5.420000e-08      2
# 1    -5.0  38.750                0.000414                3.570000e-08      3
# 2    -5.0  38.750                0.000404                5.430000e-08      3
# 3    -5.0  38.750                0.000398                2.360000e-08      1
# 4    -5.0  38.750                0.000399                1.800000e-08      3
# ...   ...     ...                     ...                         ...    ...
# 4226  4.5  35.000                0.000407                4.340000e-08     11
# 4227  4.5  35.625                0.000415                5.680000e-08      5
# 4228  4.5  35.625                0.000414                4.840000e-08      1
# 4229  4.5  35.625                0.000401                4.260000e-08     12
# 4230  4.5  35.625                0.000411                3.390000e-08      9
#
# ...

# %% [markdown]
# ## Plotting

# %%
#Sort the data to sort the x-axis
data=data.sort_values(by=['Year', "Month"])

# %%
data
# Out:
#       lat     lon  XCO2 (mol CO2/mol dry)  XCO2PREC (mol CO2/mol dry)  Month  \
# 3    -5.0  38.750                0.000398                2.360000e-08      1
# 49   -4.5  38.750                0.000398                2.390000e-08      1
# 127  -4.5  39.375                0.000398                2.200000e-08      1
# 128  -4.5  39.375                0.000398                2.200000e-08      1
# 129  -4.5  39.375                0.000398                2.200000e-08      1
# ...   ...     ...                     ...                         ...    ...
# 4056  4.0  33.750                0.000416                4.910000e-08     12
# 4085  4.0  34.375                0.000416                4.650000e-08     12
# 4111  4.0  35.000                0.000416                4.360000e-08     12
# 4148  4.5  34.375                0.000416                4.700000e-08     12
# 4193  4.5  35.000                0.000416                4.400000e-08     12
#
# ...

# %%
myx = data[(data['Year'] == 2015) & (data['primary_fuel'] == 'Oil')]['year_month']
myy = data[(data['Year'] == 2015) & (data['primary_fuel'] == 'Oil')]['XCO2 (mol CO2/mol dry)']

# %%
myx2 = data[(data['Year'] == 2015) & (data['primary_fuel'] == 'Hydro')]['year_month']
myy2 = data[(data['Year'] == 2015) & (data['primary_fuel'] == 'Hydro')]['XCO2 (mol CO2/mol dry)']

# %%
plt.plot(myx, myy, label='Oil')
plt.plot(myx2, myy2, label='Hydro')
plt.gcf().set_size_inches(10, 10)
plt.legend()
plt.show()
