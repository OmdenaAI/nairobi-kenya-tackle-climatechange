# %% [markdown]
# # DATA PREPROCESSING

# %%
#TO PRE-PROCESS DATA\n",
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#TO READ CSV FILE
data = pd.read_csv(r"E:\final data.csv")

# %%
data
# Out:
#       lat     lon  XCO2 (mol CO2/mol dry)  XCO2PREC (mol CO2/mol dry)  Month  \
# 0    -5.0  38.750                0.000414                5.421756e-08      2
# 1    -5.0  38.750                0.000414                3.570844e-08      3
# 2    -5.0  38.750                0.000404                5.427318e-08      3
# 3    -5.0  38.750                0.000398                2.360435e-08      1
# 4    -5.0  38.750                0.000399                1.796053e-08      3
# ...   ...     ...                     ...                         ...    ...
# 4226  4.5  35.000                0.000407                4.341377e-08     11
# 4227  4.5  35.625                0.000415                5.676942e-08      5
# 4228  4.5  35.625                0.000414                4.844761e-08      1
# 4229  4.5  35.625                0.000401                4.263339e-08     12
# 4230  4.5  35.625                0.000411                3.387692e-08      9
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4231 entries, 0 to 4230
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   lat                         4231 non-null   float64
#  1   lon                         4231 non-null   float64
#  2   XCO2 (mol CO2/mol dry)      4231 non-null   float64
#  3   XCO2PREC (mol CO2/mol dry)  4231 non-null   float64
#  4   Month                       4231 non-null   int64
#  5   Year                        4231 non-null   int64
#  6   DATE                        4231 non-null   object
#  7   population                  3563 non-null   float64
#  8   primary_fuel                818 non-null    object
#  9   commissioning_year          818 non-null    float64
#  10  capacity_mw                 818 non-null    float64
#  11  city_ascii                  2212 non-null   object
#  12  capital                     1509 non-null   object
# ...

# %%
data.isnull().sum()
# Out:
# lat                              0
# lon                              0
# XCO2 (mol CO2/mol dry)           0
# XCO2PREC (mol CO2/mol dry)       0
# Month                            0
# Year                             0
# DATE                             0
# population                     668
# primary_fuel                  3413
# commissioning_year            3413
# capacity_mw                   3413
# city_ascii                    2019
# capital                       2722
# city_pop_2022                 2605
# month                            0
# brightness                       0
# scan                             0
# track                            0
# bright_t31                       0
# frp                              0
# dtype: int64

# %%
data['population']
# Out:
# 0             NaN
# 1             NaN
# 2       76316.340
# 3       71487.750
# 4       71487.750
#           ...
# 4226    33335.830
# 4227          NaN
# 4228          NaN
# 4229    16838.428
# 4230    19669.621
# Name: population, Length: 4231, dtype: float64

# %%
#FILLING THE NAN VALUE(NOT AVAILABLE VALUE) WITH ZERO\n",
data['population'].fillna(0, inplace=True)

# %%
data['population']
# Out:
# 0           0.000
# 1           0.000
# 2       76316.340
# 3       71487.750
# 4       71487.750
#           ...
# 4226    33335.830
# 4227        0.000
# 4228        0.000
# 4229    16838.428
# 4230    19669.621
# Name: population, Length: 4231, dtype: float64

# %%
data['city_ascii']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 4226    NaN
# 4227    NaN
# 4228    NaN
# 4229    NaN
# 4230    NaN
# Name: city_ascii, Length: 4231, dtype: object

# %%
data['capital']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 4226    NaN
# 4227    NaN
# 4228    NaN
# 4229    NaN
# 4230    NaN
# Name: capital, Length: 4231, dtype: object

# %%
data['city_pop_2022']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 4226   NaN
# 4227   NaN
# 4228   NaN
# 4229   NaN
# 4230   NaN
# Name: city_pop_2022, Length: 4231, dtype: float64

# %%
#DROPPING UNWANTED COLUMNS\n",
del data['city_ascii']

# %%
del data['capital']

# %%
del data['city_pop_2022']

# %%
data
# Out:
#       lat     lon  XCO2 (mol CO2/mol dry)  XCO2PREC (mol CO2/mol dry)  Month  \
# 0    -5.0  38.750                0.000414                5.421756e-08      2
# 1    -5.0  38.750                0.000414                3.570844e-08      3
# 2    -5.0  38.750                0.000404                5.427318e-08      3
# 3    -5.0  38.750                0.000398                2.360435e-08      1
# 4    -5.0  38.750                0.000399                1.796053e-08      3
# ...   ...     ...                     ...                         ...    ...
# 4226  4.5  35.000                0.000407                4.341377e-08     11
# 4227  4.5  35.625                0.000415                5.676942e-08      5
# 4228  4.5  35.625                0.000414                4.844761e-08      1
# 4229  4.5  35.625                0.000401                4.263339e-08     12
# 4230  4.5  35.625                0.000411                3.387692e-08      9
#
# ...

# %%
data.isnull().sum()
# Out:
# lat                              0
# lon                              0
# XCO2 (mol CO2/mol dry)           0
# XCO2PREC (mol CO2/mol dry)       0
# Month                            0
# Year                             0
# DATE                             0
# population                       0
# primary_fuel                  3413
# commissioning_year            3413
# capacity_mw                   3413
# capital                       2722
# month                            0
# brightness                       0
# scan                             0
# track                            0
# bright_t31                       0
# frp                              0
# dtype: int64

# %%
#FILLING THE NAN VALUE(NOT AVAILABLE VALUE) WITH ZERO\n",
data['primary_fuel'].fillna(0, inplace=True)

# %%
data['commissioning_year'].fillna(0, inplace=True)

# %%
data['capacity_mw'].fillna(0, inplace=True)

# %%
data['capital'].fillna(0, inplace=True)

# %%
data['primary_fuel']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4226    0
# 4227    0
# 4228    0
# 4229    0
# 4230    0
# Name: primary_fuel, Length: 4231, dtype: object

# %%
data.isnull().sum()
# Out:
# lat                           0
# lon                           0
# XCO2 (mol CO2/mol dry)        0
# XCO2PREC (mol CO2/mol dry)    0
# Month                         0
# Year                          0
# DATE                          0
# population                    0
# primary_fuel                  0
# commissioning_year            0
# capacity_mw                   0
# capital                       0
# month                         0
# brightness                    0
# scan                          0
# track                         0
# bright_t31                    0
# frp                           0
# dtype: int64

# %%
data
# Out:
#       lat     lon  XCO2 (mol CO2/mol dry)  XCO2PREC (mol CO2/mol dry)  Month  \
# 0    -5.0  38.750                0.000414                5.421756e-08      2
# 1    -5.0  38.750                0.000414                3.570844e-08      3
# 2    -5.0  38.750                0.000404                5.427318e-08      3
# 3    -5.0  38.750                0.000398                2.360435e-08      1
# 4    -5.0  38.750                0.000399                1.796053e-08      3
# ...   ...     ...                     ...                         ...    ...
# 4226  4.5  35.000                0.000407                4.341377e-08     11
# 4227  4.5  35.625                0.000415                5.676942e-08      5
# 4228  4.5  35.625                0.000414                4.844761e-08      1
# 4229  4.5  35.625                0.000401                4.263339e-08     12
# 4230  4.5  35.625                0.000411                3.387692e-08      9
#
# ...
