# %% [markdown]
# # DATA PREPROCESSING

# %%
pip install param
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install panel
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pydeck
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#TO PRE-PROCESS DATA\n",
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#TO READ CSV FILE
data = pd.read_csv(r"E:\global_power_plant_database.csv")
# Out:
# <ipython-input-27-0c8aae0bb943>:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(r"E:\global_power_plant_database.csv")

# %%
data
# Out:
#       country country_long                                               name  \
# 0         AFG  Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 1         AFG  Afghanistan                                       Kandahar DOG
# 2         AFG  Afghanistan                                       Kandahar JOL
# 3         AFG  Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 4         AFG  Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# ...       ...          ...                                                ...
# 34931     ZMB       Zambia                                              Ndola
# 34932     ZMB       Zambia                                              Nkana
# 34933     ZMB       Zambia                                     Victoria Falls
# 34934     ZWE     Zimbabwe                   Hwange Coal Power Plant Zimbabwe
# 34935     ZWE     Zimbabwe  Kariba Dam South Hydroelectric Power Station Z...
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34936 entries, 0 to 34935
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   country                         34936 non-null  object
#  1   country_long                    34936 non-null  object
#  2   name                            34936 non-null  object
#  3   gppd_idnr                       34936 non-null  object
#  4   capacity_mw                     34936 non-null  float64
#  5   latitude                        34936 non-null  float64
#  6   longitude                       34936 non-null  float64
#  7   primary_fuel                    34936 non-null  object
#  8   other_fuel1                     1944 non-null   object
#  9   other_fuel2                     276 non-null    object
#  10  other_fuel3                     92 non-null     object
#  11  commissioning_year              17447 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# country                               0
# country_long                          0
# name                                  0
# gppd_idnr                             0
# capacity_mw                           0
# latitude                              0
# longitude                             0
# primary_fuel                          0
# other_fuel1                       32992
# other_fuel2                       34660
# other_fuel3                       34844
# commissioning_year                17489
# owner                             14068
# source                               15
# url                                  18
# geolocation_source                  419
# wepp_id                           18702
# year_of_capacity_data             20049
# generation_gwh_2013               28519
# generation_gwh_2014               27710
# generation_gwh_2015               26733
# generation_gwh_2016               25792
# generation_gwh_2017               25436
# ...

# %%
#EXTRACT DATA OF KENYA ONLY"
kenya= data.loc[data['country_long'] == 'Kenya']

# %%
kenya
# Out:
#       country country_long                                         name  \
# 17066     KEN        Kenya                                      Garissa
# 17067     KEN        Kenya                                       Gitaru
# 17068     KEN        Kenya  Iberafrica I & II (Nairobi south diesel PP)
# 17069     KEN        Kenya                                      Kamburu
# 17070     KEN        Kenya                                     Kiambere
# 17071     KEN        Kenya                                    Kindaruma
# 17072     KEN        Kenya                                     Kipevu I
# 17073     KEN        Kenya                            Kipevu II (Tsavo)
# 17074     KEN        Kenya                                   Kipevu III
# 17075     KEN        Kenya                                 Lake Turkana
# 17076     KEN        Kenya                                      Masinga
# 17077     KEN        Kenya                                        Ngong
# ...

# %%
#DROPPING UNWANTED COLUMNS\n",
del kenya['other_fuel2']

# %%
del kenya['other_fuel1']

# %%
del kenya['other_fuel3']

# %%
del kenya['year_of_capacity_data']

# %%
del kenya['generation_gwh_2013']

# %%
del kenya['generation_gwh_2014']

# %%
del kenya['generation_gwh_2015']

# %%
del kenya['generation_gwh_2016']

# %%
del kenya['generation_gwh_2017']

# %%
del kenya['generation_gwh_2018']

# %%
del kenya['generation_gwh_2019']

# %%
del kenya['generation_data_source']

# %%
kenya.isnull().sum()
# Out:
# country                            0
# country_long                       0
# name                               0
# gppd_idnr                          0
# capacity_mw                        0
# latitude                           0
# longitude                          0
# primary_fuel                       0
# commissioning_year                 2
# owner                              1
# source                             0
# url                                0
# geolocation_source                 0
# wepp_id                            4
# estimated_generation_gwh_2013     13
# estimated_generation_gwh_2014     13
# estimated_generation_gwh_2015     13
# estimated_generation_gwh_2016     13
# estimated_generation_gwh_2017      0
# estimated_generation_note_2013     0
# estimated_generation_note_2014     0
# estimated_generation_note_2015     0
# estimated_generation_note_2016     0
# estimated_generation_note_2017     0
# dtype: int64

# %%
kenya.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'commissioning_year', 'owner',
#        'source', 'url', 'geolocation_source', 'wepp_id',
#        'estimated_generation_gwh_2013', 'estimated_generation_gwh_2014',
#        'estimated_generation_gwh_2015', 'estimated_generation_gwh_2016',
#        'estimated_generation_gwh_2017', 'estimated_generation_note_2013',
#        'estimated_generation_note_2014', 'estimated_generation_note_2015',
#        'estimated_generation_note_2016', 'estimated_generation_note_2017'],
#       dtype='object')

# %%
kenya.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 17066 to 17088
# Data columns (total 24 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   country                         23 non-null     object
#  1   country_long                    23 non-null     object
#  2   name                            23 non-null     object
#  3   gppd_idnr                       23 non-null     object
#  4   capacity_mw                     23 non-null     float64
#  5   latitude                        23 non-null     float64
#  6   longitude                       23 non-null     float64
#  7   primary_fuel                    23 non-null     object
#  8   commissioning_year              21 non-null     float64
#  9   owner                           22 non-null     object
#  10  source                          23 non-null     object
#  11  url                             23 non-null     object
# ...

# %%
#FILLING THE NAN VALUE(NOT AVAILABLE VALUE) WITH ZERO\n",
kenya['wepp_id'].fillna(0, inplace=True)
# Out:
# <ipython-input-48-7cc29af60419>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kenya['wepp_id'].fillna(0, inplace=True)

# %%
kenya['estimated_generation_gwh_2014'].fillna(0, inplace=True)
# Out:
# <ipython-input-49-0490e06ef9a6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kenya['estimated_generation_gwh_2014'].fillna(0, inplace=True)

# %%
kenya['estimated_generation_gwh_2015'].fillna(0, inplace=True)
# Out:
# <ipython-input-50-0be7d58642f6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kenya['estimated_generation_gwh_2015'].fillna(0, inplace=True)

# %%
kenya['estimated_generation_gwh_2016'].fillna(0, inplace=True)
# Out:
# <ipython-input-51-998e920c84b2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kenya['estimated_generation_gwh_2016'].fillna(0, inplace=True)

# %%
kenya['estimated_generation_gwh_2013'].fillna(0, inplace=True)
# Out:
# <ipython-input-52-7dd28717b0a8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kenya['estimated_generation_gwh_2013'].fillna(0, inplace=True)

# %%
kenya['owner'].fillna('NOT AVAILABLE',inplace=True)
# Out:
# <ipython-input-53-e7fc9a7ac979>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kenya['owner'].fillna('NOT AVAILABLE',inplace=True)

# %%
kenya['commissioning_year'].fillna(0, inplace=True)
# Out:
# <ipython-input-54-852721eb0eac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kenya['commissioning_year'].fillna(0, inplace=True)

# %%
kenya.isnull().sum()
# Out:
# country                           0
# country_long                      0
# name                              0
# gppd_idnr                         0
# capacity_mw                       0
# latitude                          0
# longitude                         0
# primary_fuel                      0
# commissioning_year                0
# owner                             0
# source                            0
# url                               0
# geolocation_source                0
# wepp_id                           0
# estimated_generation_gwh_2013     0
# estimated_generation_gwh_2014     0
# estimated_generation_gwh_2015     0
# estimated_generation_gwh_2016     0
# estimated_generation_gwh_2017     0
# estimated_generation_note_2013    0
# estimated_generation_note_2014    0
# estimated_generation_note_2015    0
# estimated_generation_note_2016    0
# estimated_generation_note_2017    0
# dtype: int64

# %%
kenya
# Out:
#       country country_long                                         name  \
# 17066     KEN        Kenya                                      Garissa
# 17067     KEN        Kenya                                       Gitaru
# 17068     KEN        Kenya  Iberafrica I & II (Nairobi south diesel PP)
# 17069     KEN        Kenya                                      Kamburu
# 17070     KEN        Kenya                                     Kiambere
# 17071     KEN        Kenya                                    Kindaruma
# 17072     KEN        Kenya                                     Kipevu I
# 17073     KEN        Kenya                            Kipevu II (Tsavo)
# 17074     KEN        Kenya                                   Kipevu III
# 17075     KEN        Kenya                                 Lake Turkana
# 17076     KEN        Kenya                                      Masinga
# 17077     KEN        Kenya                                        Ngong
# ...

# %% [markdown]
# # Transform the data

# %%
import param
import panel as pn
import pydeck as pdk
pn.extension('deckgl', sizing_mode="stretch_width")
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
FUEL_COLORS = {
    "Oil": "black",
    "Solar": "green",
    "Gas": "black",
    "Other": "gray",
    "Hydro": "blue",
    "Coal": "black",
    "Petcoke": "black",
    "Biomass": "green",
    "Waste": "green",
    "Cogeneration": "gray",
    "Storage": "orange",
    "Wind": "green",
}

COLORS_R = {"black": 0, "green": 0, "blue": 0, "orange": 255, "gray": 128}
COLORS_G = {"black": 0, "green": 128, "blue": 0, "orange": 165, "gray": 128}
COLORS_B = {"black": 0, "green": 0, "blue": 255, "orange": 0, "gray": 128}

kenya["primary_fuel_color"] = kenya.primary_fuel.map(FUEL_COLORS)
kenya["primary_fuel_color"] = kenya["primary_fuel_color"].fillna("gray")
kenya["color_r"] = kenya["primary_fuel_color"].map(COLORS_R)
kenya["color_g"] = kenya["primary_fuel_color"].map(COLORS_G)
kenya["color_b"] = kenya["primary_fuel_color"].map(COLORS_B)
kenya["color_a"] = 140

# "name", "primary_fuel", "capacity_mw",
kenya = kenya[[
    "latitude","longitude", "name", "capacity_mw",
    "color_r","color_g","color_b","color_a",]
]
kenya.head(1)
# Out:
# <ipython-input-58-8b95c835e93a>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kenya["primary_fuel_color"] = kenya.primary_fuel.map(FUEL_COLORS)
# <ipython-input-58-8b95c835e93a>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kenya["primary_fuel_color"] = kenya["primary_fuel_color"].fillna("gray")
# <ipython-input-58-8b95c835e93a>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# ...

# %% [markdown]
# # Create the app

# %%
class GlobalPowerPlantDatabaseApp(param.Parameterized):
    
    data = param.DataFrame(kenya, precedence=-1)

    opacity = param.Number(default=0.8, step=0.05, bounds=(0, 1))
    
    pitch = param.Number(default=0, bounds=(0, 90))
    
    zoom = param.Integer(default=1, bounds=(1, 10))
    
    def __init__(self, **params):
        super(GlobalPowerPlantDatabaseApp, self).__init__(**params)
        self._view_state = pdk.ViewState(
            latitude=52.2323,
            longitude=-1.415,
            zoom=self.zoom,
            min_zoom=self.param.zoom.bounds[0],
            max_zoom=self.param.zoom.bounds[1],
        )
        self._scatter = pdk.Layer(
            "ScatterplotLayer",
            data=self.data,
            get_position=["longitude", "latitude"],
            get_fill_color="[color_r, color_g, color_b, color_a]",
            get_radius="capacity_mw*10",
            pickable=True,
            opacity=self.opacity,
            filled=True,
            wireframe=True,
        )
        self._deck = pdk.Deck(
            map_style="mapbox://styles/mapbox/light-v9",
            initial_view_state=self._view_state,
            layers=[self._scatter],
            tooltip=True,
            #api_keys={'mapbox': MAPBOX_KEY},
        )
        self.pane = pn.pane.DeckGL(self._deck, sizing_mode="stretch_width", height=700)
        self.param.watch(self._update, ['data', 'opacity', 'pitch', 'zoom'])

    #@pn.depends('pane.hover_state', 'data')
    def _info(self):
        index = self.pane.hover_state.get('index', -1)
        if index == -1:
            index = slice(0, 0)
        return self.data.iloc[index][['name', 'capacity_mw']]
    
    #@pn.depends('pane.view_State', watch=True)
    def _update(self):
        state = self.pane.view_state
        self._view_state.longitude = state['longitude']
        self._view_state.latitude = state['latitude']   

    def _update(self, event):
        if event.name == 'data':
            self._scatter.data = self.data
        if event.name == 'opacity':
            self._scatter.opacity = self.opacity
        if event.name == 'zoom':
            self._view_state.zoom = self.zoom
        if event.name == 'pitch':
            self._view_state.pitch = self.pitch
        self.pane.param.trigger('object')
    
    def view(self):
        return pn.Row(pn.Column(self.param, pn.panel(self._info, height=200)), self.pane)

component = GlobalPowerPlantDatabaseApp()
component.view()
# Out:
# Row(sizing_mode='stretch_width')
#     [0] Column(sizing_mode='stretch_width')
#         [0] Column(margin=5, name='GlobalPowerPlantDatabaseA..., sizing_mode='stretch_width', width=300)
#             [0] StaticText(sizing_mode='stretch_width', value='<b>GlobalPowerPlantDataba...)
#             [1] FloatSlider(name='Opacity', sizing_mode='stretch_width', step=0.05, value=0.8)
#             [2] FloatSlider(end=90, name='Pitch', sizing_mode='stretch_width')
#             [3] IntSlider(end=10, name='Zoom', sizing_mode='stretch_width', start=1, value=1)
#         [1] ParamMethod(method, height=200, sizing_mode='stretch_width')
#     [1] DeckGL(Deck, height=700, sizing_mode='stretch_width')
